# %% [markdown]
# <a href="https://colab.research.google.com/github/yuricasilvanadeassiscaetano120713-beep/MachineLearningCodes/blob/main/Copy_of_Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from google.colab import files
import io

# %%
uploaded = files.upload()

# Automatically get the uploaded filename
filename = next(iter(uploaded))

# Read the CSV file into a pandas DataFrame
dataset = pd.read_csv(io.BytesIO(uploaded[filename]))
# Out:
#      <input type="file" id="files-4a0b6570-7ff3-407b-91e2-171fb39788a8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4a0b6570-7ff3-407b-91e2-171fb39788a8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
dataset.describe()
# Out:
#                  x           y
# count   700.000000  699.000000
# mean     54.985939   49.939869
# std     134.681703   29.109217
# min       0.000000   -3.839981
# 25%      25.000000   24.929968
# 50%      49.000000   48.973020
# 75%      75.000000   74.929911
# max    3530.157369  108.871618

# %%
x = dataset.iloc[0:700,0:1]
y = dataset.iloc[0:700,1:2]

# %%
x
# Out:
#         x
# 0    24.0
# 1    50.0
# 2    15.0
# 3    38.0
# 4    87.0
# ..    ...
# 695  58.0
# 696  93.0
# 697  82.0
# 698  66.0
# 699  97.0
#
# [700 rows x 1 columns]

# %%
x.boxplot(column=['x'])
# Out:
# <Axes: >

# %%
y.boxplot(column=['y'])
# Out:
# <Axes: >

# %%
#plot THE SCATTER PLOT
plt.scatter(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title("X vs Y scatter Plot")
# Out:
# Text(0.5, 1.0, 'X vs Y scatter Plot')

# %%
#linear regression
def hypothesis(thetha_array,x):
  return theta_array[0]+theta_aray[1]*x

# %%
def const_function(theta_array, x, y, m):
  errors=0
  for i in range(m):
    error = error+ ((theta_array[0]+theta_array[1]*x[i])-y[i])**2
  return error/(2*m)

# %%
def gradient_descent(theta_array, x, y, m, alpha):
  somation_0 = 0
  somation_1 = 0
  for i in range(m):
    somation_0 += ((theta_array[0]+theta_array[1]*x[i])-y[i])
    somation_1 += x[i]*((theta_array[0]+theta_array[1]*x[i])-y[i])

    new_theta0 = theta_array[0] - (alpha/m)*somation_0
    new_theta1 = theta_array[1] - (alpha/m)*somation_1
    updated_new_theta = [new_theta0, new_theta1]
  return updated_new_theta

# %%
def training(x, y, alpha, iters):
  theta0 = 0
  theta1 = 0
  theta_array = [theta0, theta1]
  m = x.size

  for i in range(iters):
    theta_array = gradient_descent(theta_array, x, y, m, alpha)
    cost_values.append(cost_function(theta_array,x,y,m))
    y_predict = x*thetha_array[1]+theta_array[0]
    plt.plot(y_predict,x,'r')
    plt.scatter(x,y)
    plt.show()
    cost_function(theta_array, x, y, m)
  return cost_values

# %%
#feeding the input data
training_data = dataset.dropna()

# %%
training_data.shape
# Out:
# (699, 2)

# %%
x_value = training_data['x']
y_value = training_data['y']

# %%
type(x_value)
# Out:
# pandas.core.series.Series

# %%
x_value = x_value.values.reshape(x_value.shape[0],1)
y_value = y_value.values.reshape(y_value.shape[0],1)

# %%
type(x_value)
# Out:
# numpy.ndarray

# %%
alpha = 0.0001
iters = 50
cost_values, theta_array = training(x_value, y_value, alpha, iters)
x_axis = np.arange(0, len(cost_values), step=1)
plt.plot(x_axis, cost_values)
plt.xlabel("iterations")
plt.ylabel("cost_values")
plt.title("Loss Graph")
plt.show()
print(theta_array)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-58-903966138.py in <cell line: 0>()
#       1 alpha = 0.0001
#       2 iters = 50
# ----> 3 cost_values, theta_array = training(x_value, y_value, alpha, iters)
#       4 x_axis = np.arange(0, len(cost_values), step=1)
#       5 plt.plot(x_axis, cost_values)
#
# /tmp/ipython-input-35-922996322.py in training(x, y, alpha, iters)
#       7   for i in range(iters):
#       8     theta_array = gradient_descent(theta_array, x, y, m, alpha)
# ----> 9     cost_values.append(cost_function(theta_array,x,y,m))
#      10     y_predict = x*thetha_array[1]+theta_array[0]
#      11     plt.plot(y_predict,x,'r')
#
# NameError: name 'cost_values' is not defined

# %%
hypothesis(theta_array, 12.0)

# %%
""""Homework
Observe the loss function curve for
alpha= 0.00000001, 0.0000001, 0.01, 1, 5, 10, 100
""""
